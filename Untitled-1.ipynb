# %%
# %pip install numpy
import numpy as np
a=np.zeros((3,3))
a
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().run_line_magic('pip', 'install numpy')
# ----> 2 import numpy as np
#       3 a=np.zeros((3,3))
#       4 a
#
# File c:\cprogram\prgforpython.py\numpy.py:2
#       1 import numpy as np
# ----> 2 a=np.array([0,1,2,3])
#       4 print(a)
#
# AttributeError: module 'numpy' has no attribute 'array' (consider renaming 'c:\cprogram\prgforpython.py\numpy.py' if it has the same name as a library you intended to import)
